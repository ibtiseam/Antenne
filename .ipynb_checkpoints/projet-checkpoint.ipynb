# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
df=pd.read_csv('ANFR_Herault_Mesures_originales_pour_jpynb_V2.csv', delimiter=';')
df.head()
# Out:
#    Numero de mesure  Longitude  Latitude  \
# 0               175    3.91611  43.58528
# 1               180    4.04194  43.64694
# 2               543    3.03167  43.36028
# 3               545    3.03278  43.36167
# 4               850    3.56444  43.64583
#
#                                     Position  Insee  \
# 0  03e 54' 58.00'' Est, 43e 35' 07.00'' Nord  34129
# 1  04e 02' 31.00'' Est, 43e 38' 49.00'' Nord  34176
# 2  03e 01' 54.00'' Est, 43e 21' 37.00'' Nord  34225
# 3  03e 01' 58.00'' Est, 43e 21' 42.00'' Nord  34225
# 4  03e 33' 52.00'' Est, 43e 38' 45.00'' Nord  34114
#
#                                Adresse                 Complement  \
# 0                           Mas de Gau                        NaN
# 1  5539 Rue Lou Claou de la Oulivettas                        NaN
# 2                 Chemin de Montfaucon  residence de  Mme SOUTADE
# 3                   Chemin de Quarante  residence de  M. GONZALEZ
# ...

# %%
df.rename(columns={'Niveau global': 'Niveau_global'}, inplace=True)

# %%
df=df.assign(target=1)

# %%
# A list with missing entries
def add_line ():
    for i in range(0,10):
        Niveau_glb = random.uniform(1,6)
        Numéro_de_mesure =random.randint(2000,4000)
        row_contents = [Numéro_de_mesure, 3.91611,43.64694, 'Est, 43e 35 07.00 Nord',34176,
       'Chemin de Montfaucon','residence de Mme SOUTADE',34130,'LATTES','06/12/2001','En exterieure', 
                    'FicheMesure175.pdf', 'Oui', Niveau_glb, 'Divers', 'SATELIT', 1]
        # Appending a row to csv with missing entries
        append_list_as_row('ANFR_Herault_Mesures_originales_pour_jpynb_V2.csv', row_contents)

# %%
add_line()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dbec08eac388> in <module>
# ----> 1 add_line()
#
# <ipython-input-15-e9baecdcb408> in add_line()
#       8                     'FicheMesure175.pdf', 'Oui', Niveau_glb, 'Divers', 'SATELIT', 1]
#       9         # Appending a row to csv with missing entries
# ---> 10         append_list_as_row('ANFR_Herault_Mesures_originales_pour_jpynb_V2.csv', row_contents)
#
# NameError: name 'append_list_as_row' is not defined
